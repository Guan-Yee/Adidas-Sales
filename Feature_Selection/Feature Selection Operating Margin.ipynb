B

# %%
y_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5842 entries, 0 to 5841
# Data columns (total 1 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Operating Margin  5842 non-null   int64
# dtypes: int64(1)
# memory usage: 45.8 KB

# %% [markdown]
# Allocate into respective category

# %%
# select numerical variables
numerical_cols = ['Price per Unit', 'Units Sold']
x_train_numerical = x_train[numerical_cols]

# select categorical variables
categorical_cols = ['Month', 'Day', 'Gender', 
       'Retailer_Amazon', 'Retailer_Foot Locker', "Retailer_Kohl's",
       'Retailer_Sports Direct', 'Retailer_Walmart', 'Retailer_West Gear',
       'Region_Midwest', 'Region_Northeast', 'Region_South',
       'Region_Southeast', 'Region_West', 'Sales Method_In-store',
       'Sales Method_Online', 'Sales Method_Outlet', 'Product_ Apparel',
       'Product_ Athletic Footwear', 'Product_ Street Footwear',
       'State_Alabama', 'State_Alaska', 'State_Arizona', 'State_Arkansas',
       'State_California', 'State_Connecticut', 'State_Delaware',
       'State_Florida', 'State_Georgia', 'State_Hawaii', 'State_Idaho',
       'State_Illinois', 'State_Indiana', 'State_Iowa', 'State_Kansas',
       'State_Kentucky', 'State_Louisiana', 'State_Maine', 'State_Maryland',
       'State_Massachusetts', 'State_Michigan', 'State_Mississippi',
       'State_Missouri', 'State_Montana', 'State_Nebraska',
       'State_New Hampshire', 'State_New Jersey', 'State_New Mexico',
       'State_New York', 'State_North Carolina', 'State_North Dakota',
       'State_Ohio', 'State_Oklahoma', 'State_Oregon', 'State_Pennsylvania',
       'State_Rhode Island', 'State_South Carolina', 'State_South Dakota',
       'State_Tennessee', 'State_Texas', 'State_Utah', 'State_Vermont',
       'State_Virginia', 'State_West Virginia', 'State_Wisconsin',
       'State_Wyoming']
x_train_categorical = x_train[categorical_cols]

# %% [markdown]
# Numerical variables

# %%
# Creating the correlation matrix
corr_matrix = x_train[numerical_cols].corr()

# show correlation matrix with numbers
corr_matrix.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_7e7eb_row0_col0, #T_7e7eb_row1_col1 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_7e7eb_row0_col1, #T_7e7eb_row1_col0 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_7e7eb" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7e7eb_level0_col0" class="col_heading level0 col0" >Price per Unit</th>
#       <th id="T_7e7eb_level0_col1" class="col_heading level0 col1" >Units Sold</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7e7eb_level0_row0" class="row_heading level0 row0" >Price per Unit</th>
#       <td id="T_7e7eb_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_7e7eb_row0_col1" class="data row0 col1" >0.269190</td>
#     </tr>
#     <tr>
#       <th id="T_7e7eb_level0_row1" class="row_heading level0 row1" >Units Sold</th>
#       <td id="T_7e7eb_row1_col0" class="data row1 col0" >0.269190</td>
#       <td id="T_7e7eb_row1_col1" class="data row1 col1" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# The correlation between the Price per unit and Units sold is not significant.

# %% [markdown]
# Mutual information

# %%
from sklearn.feature_selection import mutual_info_regression

# Compute mutual information between each feature in X and y
mutual_info1 = mutual_info_regression(x_train_numerical, y_train, random_state=42)

# Create a DataFrame to store the mutual information scores for each feature
mi_df1 = pd.DataFrame({'feature': numerical_cols, 'mi_score': mutual_info1})

# Sort the features by their mutual information scores in descending order
mi_df1 = mi_df1.sort_values(by='mi_score', ascending=False)

# Print the mutual information scores for each feature
mi_df1
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
#           feature  mi_score
# 1      Units Sold  0.386740
# 0  Price per Unit  0.276167

# %% [markdown]
# Categorical variables

# %%
from sklearn.feature_selection import mutual_info_regression

# Compute mutual information between each feature in X and y
mutual_info2 = mutual_info_regression(x_train_categorical, y_train, random_state=42)

# Create a DataFrame to store the mutual information scores for each feature
mi_df2 = pd.DataFrame({'feature': categorical_cols, 'mi_score': mutual_info2})

# Sort the features by their mutual information scores in descending order
mi_df2 = mi_df2.sort_values(by='mi_score', ascending=False)

# Print the mutual information scores for each feature
mi_df2
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
#                   feature  mi_score
# 14  Sales Method_In-store  0.164026
# 15    Sales Method_Online  0.120423
# 16    Sales Method_Outlet  0.094239
# 11           Region_South  0.040137
# 0                   Month  0.034653
# ..                    ...       ...
# 47       State_New Mexico  0.000000
# 55     State_Rhode Island  0.000000
# 32          State_Indiana  0.000000
# 30            State_Idaho  0.000000
# 65          State_Wyoming  0.000000
#
# [66 rows x 2 columns]

# %%
mi_df2[1:33]
# Out:
#                      feature  mi_score
# 15       Sales Method_Online  0.120423
# 16       Sales Method_Outlet  0.094239
# 11              Region_South  0.040137
# 0                      Month  0.034653
# 1                        Day  0.033383
# 17          Product_ Apparel  0.030929
# 39       State_Massachusetts  0.025014
# 13               Region_West  0.024819
# 9             Region_Midwest  0.022251
# 29              State_Hawaii  0.022065
# 20             State_Alabama  0.021679
# 27             State_Florida  0.020547
# 6     Retailer_Sports Direct  0.020372
# 2                     Gender  0.019815
# 8         Retailer_West Gear  0.019699
# 34              State_Kansas  0.019152
# 42            State_Missouri  0.018279
# 37               State_Maine  0.017440
# 22             State_Arizona  0.017423
# 59               State_Texas  0.016897
# 21              State_Alaska  0.016775
# 19  Product_ Street Footwear  0.016745
# 53              State_Oregon  0.016081
# 33                State_Iowa  0.016007
# 12          Region_Southeast  0.014955
# 3            Retailer_Amazon  0.012899
# 64           State_Wisconsin  0.012384
# 49      State_North Carolina  0.011387
# 63       State_West Virginia  0.011356
# 43             State_Montana  0.011353
# 46          State_New Jersey  0.010981
# 61             State_Vermont  0.010803

# %%
mi_df2[33:66]
# Out:
#                        feature  mi_score
# 56        State_South Carolina  0.010765
# 40              State_Michigan  0.010744
# 60                  State_Utah  0.010591
# 48              State_New York  0.010192
# 10            Region_Northeast  0.009919
# 50          State_North Dakota  0.009801
# 41           State_Mississippi  0.009799
# 62              State_Virginia  0.009590
# 36             State_Louisiana  0.008936
# 58             State_Tennessee  0.008870
# 24            State_California  0.008869
# 45         State_New Hampshire  0.008788
# 35              State_Kentucky  0.008253
# 4         Retailer_Foot Locker  0.008118
# 44              State_Nebraska  0.005840
# 5              Retailer_Kohl's  0.005539
# 7             Retailer_Walmart  0.005078
# 25           State_Connecticut  0.004991
# 18  Product_ Athletic Footwear  0.004588
# 51                  State_Ohio  0.003916
# 23              State_Arkansas  0.003462
# 31              State_Illinois  0.003225
# 28               State_Georgia  0.003204
# 26              State_Delaware  0.001803
# 38              State_Maryland  0.001750
# 52              State_Oklahoma  0.001524
# 57          State_South Dakota  0.001466
# 54          State_Pennsylvania  0.000007
# 47            State_New Mexico  0.000000
# 55          State_Rhode Island  0.000000
# 32               State_Indiana  0.000000
# 30                 State_Idaho  0.000000
# 65               State_Wyoming  0.000000

# %% [markdown]
# We will drop the State_Pennsylvania, State_New Mexico, State_Rhode Island, State_Indiana, State_Idaho and State_Wyoming

# %%
x_train1 = x_train.drop(['State_Pennsylvania', 'State_New Mexico',
                         'State_Rhode Island', 'State_Indiana',
                         'State_Idaho','State_Wyoming'], axis=1)

# %%
x_test1 = x_test.drop(['State_Pennsylvania', 'State_New Mexico',
                         'State_Rhode Island', 'State_Indiana',
                         'State_Idaho','State_Wyoming'], axis=1)

# %% [markdown]
# Export the clean the dataset for the operating margin

# %%
x_train1.to_csv('/content/drive/MyDrive/Project/US Adidas Sales/Dataset/x_train_oper_clean.csv', index=False)
x_test1.to_csv('/content/drive/MyDrive/Project/US Adidas Sales/Dataset/x_test_oper_clean.csv', index=False)
